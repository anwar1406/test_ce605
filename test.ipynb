# %% [markdown]
# <a href="https://colab.research.google.com/github/anwar1406/test_ce605/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %% [markdown]
# **Hello**, This is heading **bold text**

# %% [markdown]
# [link text](https://![Vantage.JPG](data:image/jpeg;base64,...))

# %% [markdown]
# ![cpi.jpeg](data:image/jpeg;base64,...)

# %%
print("hello")
# Out:
# hello

# %%
a = 7+9
print(a)
# Out:
# 16
